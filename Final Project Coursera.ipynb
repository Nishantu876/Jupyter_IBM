# %% [markdown]
# #  "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
#  **Nishant Upadhyay**
#  Data Scientist

# %% [markdown]
# *I am interested in data science as i always had a knack for visualization and exploration of data*

# %% [markdown]
# ### Adding two numbers

# %%
a=5
b=6
print(a+b)
# Out:
# 11

# %% [markdown]
# ### Following is an unordered list
# - This is a bullet list
#     - A sub bullet
#
# ### Ordered list
# 1. This is a numbered list
#
# ***
# **below is a cheatsheet for jupyter markdown**
#
#
# __https://www.ibm.com/docs/en/db2-event-store/2.0.0?topic=notebooks-markdown-jupyter-cheatsheet__

# %%
a=5
b=7
print(a*b)
print(a+b)
# Out:
# 35
# 12

# %% [markdown]
# ### The following is an ordered list of ds Languages
#
# 1. Python
# 2. R
# 3. Java

# %% [markdown]
# ### The following is an ordered list of Ds Libraries
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. PyTorch
# 5. Scikit Learn

# %% [markdown]
# ### Converting Mins to Hours

# %%
a= 30
b= a/60
print(b)
# Out:
# 0.5

# %% [markdown]
# ### TABLE FOR DS TOOLS

# %% [markdown]
# | ApacheSpark | R studio | Jupyter Notebook |
# | --- | --- | --- |
# | Python | MongoDb | Pyspark |

# %% [markdown]
# ### AUTHOR
# ***
# ***Nishant Upadhyay***
